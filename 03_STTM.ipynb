# %%
import re
import string 

import pandas as pd
import numpy as np
from unidecode import unidecode
import nltk
from nltk.tokenize import word_tokenize
from gsdmm import MovieGroupProcess
from sklearn.feature_extraction.text import CountVectorizer

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
tweets_df_v7 = pd.read_csv("all_tweets_v7.csv", index_col=0, low_memory=False)
tweets_df_v7.head(2)
# Out:
#              author_id context_annotations      conversation_id  \
# 0  1449804331142811655                 NaN  1617597872803041280
# 1  1449804331142811655                 NaN  1617597646339702823
#
#             created_at edit_history_tweet_ids                   id  \
# 0  2023-01-23 18:59:21  [1617597872803041280]  1617597872803041280
# 1  2023-01-23 18:58:27  [1617597646339702823]  1617597646339702823
#
#    in_reply_to_user_id lang  possibly_sensitive referenced_tweets  \
# 0                  NaN   tr               False               NaN
# 1                  NaN   fr               False               NaN
#
#   reply_settings                                               text  \
# 0       everyone  Kararlarındaki temel dayanak, hukukun evrensel...
# 1       everyone  #OhalKomisyonuHukuksuzdur https://t.co/3aUr5MZWPU
#
#        author withheld  geo  quote_count  retweet_count  like_count  \
# 0  Goksun_KHK      NaN  NaN            0              2           1
# 1  Goksun_KHK      NaN  NaN            0              1           0
#
#    reply_count  impression_count                 media_keys poll_ids  \
# 0            0                82                        NaN      NaN
# 1            0                52  ['3_1617597636604723228']      NaN
#
#                                             hashtags  \
# 0  [{'start': 95, 'end': 120, 'tag': 'OhalKomisyo...
# 1  [{'start': 0, 'end': 25, 'tag': 'OhalKomisyonu...
#
#                                                 urls mentions cashtags  \
# 0                                                NaN      NaN      NaN
# 1  [{'start': 26, 'end': 49, 'url': 'https://t.co...      NaN      NaN
#
#   annotations  is_retweet gender_of_author profession_of_author  \
# 0         NaN           0              ORG        NOT AVAILABLE
# 1         NaN           0              ORG        NOT AVAILABLE
#
#          hashtags_flattened              trend_topics  n_trend_topics  \
# 0  OhalKomisyonuHukuksuzdur  OhalKomisyonuHukuksuzdur               1
# 1  OhalKomisyonuHukuksuzdur  OhalKomisyonuHukuksuzdur               1
#
#    text_length  has_media  has_hashtags  has_mentions  is_reply  \
# 0          120          0             1             0         0
# 1           49          1             1             0         0
#
#                 tweet_type  ratio_like  ratio_retweet majority_lang   english  \
# 0  no_reply_and_no_retweet    0.012195       0.024390            tr  0.874858
# 1  no_reply_and_no_retweet    0.000000       0.019231            tr  0.874858
#
#    universal  eng_astroturf  eng_fake_follower  eng_financial  eng_other  \
# 0   0.847463           0.13               0.51           0.22       0.91
# 1   0.847463           0.13               0.51           0.22       0.91
#
#    eng_overall  eng_self_declared  eng_spammer  uni_astroturf  \
# 0         0.91               0.08         0.25           0.12
# 1         0.91               0.08         0.25           0.12
#
#    uni_fake_follower  uni_financial  uni_other  uni_overall  \
# 0               0.44            0.1       0.87         0.87
# 1               0.44            0.1       0.87         0.87
#
#    uni_self_declared  uni_spammer  verified_author  followers_count_author  \
# 0               0.19         0.16            False                  1107.0
# 1               0.19         0.16            False                  1107.0
#
#    following_count_author  tweet_count_author  age_of_account_in_days_author  \
# 0                   174.0              2962.0                          470.0
# 1                   174.0              2962.0                          470.0
#
#    sentiment  created_at_day_of_week  created_at_month_of_year  \
# 0   0.994189                       0                         1
# 1   0.733746                       0                         1
#
#    created_at_time_of_day_in_seconds  reply_to_tweet_ratio  \
# 0                              68361              0.013817
# 1                              68307              0.013817
#
#    retweet_to_tweet_ratio  average_tweets_of_author_per_day
# 0                0.435233                          1.231915
# 1                0.435233                          1.231915

# %% [markdown]
# # Prepare tweets

# %%
tweets = tweets_df_v7.set_index('id')['text'].drop_duplicates()

# %%
tweets.head()
# Out:
# id
# 1617597872803041280    Kararlarındaki temel dayanak, hukukun evrensel...
# 1617597646339702823    #OhalKomisyonuHukuksuzdur https://t.co/3aUr5MZWPU
# 1617597571903676417    @Yozgat_KHK: #OhalKomisyonuHukuksuzdur\nÇünkü ...
# 1617597543000440844    #OhalKomisyonuHukuksuzdur https://t.co/FHdc5DQ0u0
# 1617597477963829248    @Malatya_KHK: Öldükten sonra insanlari işe iad...
# Name: text, dtype: object

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hasansalimkanmaz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hasansalimkanmaz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tweets = tweets.map(lambda x: re.sub('#[A-Za-z0-9]+', '', x))  # remove hashtag
tweets = tweets.map(lambda x: re.sub('@[A-Za-z0-9]+', '', x))  # remove mentions
tweets = tweets.map(lambda x: re.sub('https://t.co/[A-Za-z0-9]+', '', x)) # remove link

# tweets = tweets.map(lambda x: re.sub('[,\.!?:@]', '', x)) # remove ,.!?
tweets = tweets.map(lambda x: x.translate(str.maketrans('', '', string.punctuation + "@"))) # remove ,.!?
# new_string = a_string.translate(str.maketrans('', '', string.punctuation))

tweets = tweets.map(lambda x: re.sub('\n', '', x)) # remove \n
tweets = tweets.map(lambda x: unidecode(x)) # remove accents

# remove stopwords
stopwords = nltk.corpus.stopwords.words('turkish') 
stopwords = [unidecode(i) for i in stopwords] 
tweets = tweets.apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)])) # remove stopwords

tweets = tweets.str.lower() # lower all the words
tweets = tweets.drop_duplicates()
tweets = tweets[tweets.str.len() > 5] # selecting only tweets that are greater than 5 chars
tweets = tweets.map(word_tokenize)

# %%
tweets.head()
# Out:
# id
# 1617597872803041280    [kararlarindaki, temel, dayanak, hukukun, evre...
# 1617597571903676417    [khk, cunku, kurulma, amaci, cozum, odakli, de...
# 1617597477963829248       [khk, oldukten, sonra, insanlari, iade, yapan]
# 1617597218038349833    [khk21, talimat, kuruldutalimat, karar, verdil...
# 1617597107396804608    [khk61, kendini, anayasanin, ustunde, gorerek,...
# Name: text, dtype: object

# %% [markdown]
# # Modelling

# %%
vocab = set(token for tweet_tokens in tweets.to_list() for token in tweet_tokens)
vocab_size = len(vocab)

# %%
mgp = MovieGroupProcess(K=30, alpha=0.1, beta=0.1, n_iters=30)
y = mgp.fit(tweets.to_list(), vocab_size=vocab_size)
# Out:
# In stage 0: transferred 237855 clusters with 30 clusters populated
# In stage 1: transferred 165159 clusters with 30 clusters populated
# In stage 2: transferred 96678 clusters with 30 clusters populated
# In stage 3: transferred 58707 clusters with 30 clusters populated
# In stage 4: transferred 43424 clusters with 30 clusters populated
# In stage 5: transferred 36487 clusters with 30 clusters populated
# In stage 6: transferred 33438 clusters with 30 clusters populated
# In stage 7: transferred 31403 clusters with 30 clusters populated
# In stage 8: transferred 30903 clusters with 30 clusters populated
# In stage 9: transferred 30316 clusters with 30 clusters populated
# In stage 10: transferred 29832 clusters with 30 clusters populated
# In stage 11: transferred 29682 clusters with 30 clusters populated
# In stage 12: transferred 29452 clusters with 30 clusters populated
# In stage 13: transferred 29055 clusters with 30 clusters populated
# In stage 14: transferred 28975 clusters with 30 clusters populated
# In stage 15: transferred 29022 clusters with 30 clusters populated
# In stage 16: transferred 28782 clusters with 30 clusters populated
# In stage 17: transferred 28465 clusters with 30 clusters populated
# In stage 18: transferred 28220 clusters with 30 clusters populated
# In stage 19: transferred 28236 clusters with 30 clusters populated
# In stage 20: transferred 28105 clusters with 30 clusters populated
# In stage 21: transferred 28112 clusters with 30 clusters populated
# In stage 22: transferred 27853 clusters with 30 clusters populated
# In stage 23: transferred 27835 clusters with 30 clusters populated
# In stage 24: transferred 27930 clusters with 30 clusters populated
# In stage 25: transferred 27685 clusters with 30 clusters populated
# In stage 26: transferred 27903 clusters with 30 clusters populated
# In stage 27: transferred 27694 clusters with 30 clusters populated
# In stage 28: transferred 27877 clusters with 30 clusters populated
# In stage 29: transferred 27581 clusters with 30 clusters populated

# %%
cluster_word_distribution = mgp.cluster_word_distribution.copy()

# %%
for cluster in cluster_word_distribution:
    for word in cluster.copy().keys():
        for j, cluster_j in enumerate(cluster_word_distribution):
            if word in cluster_j and cluster_j[word] > cluster[word]:
                del cluster[word]
                break

# %%
doc_count = np.array(mgp.cluster_doc_count)
print('Number of documents per topic :', doc_count)
print('*'*20)

# Topics sorted by the number of document they are allocated to
top_index = doc_count.argsort()[::-1]
print('Most important clusters (by number of docs inside):', top_index)
print('*'*20)
# Show the top 5 words in term frequency for each cluster 
# top_words(mgp.cluster_word_distribution, top_index, 5)
for i in top_index:
    top_words = sorted(mgp.cluster_word_distribution[i].items(), key=lambda x: -x[1])[:20]
    print(f"Top words for index {i}:\n\n")
    for w in top_words:
        print(w)
    print("\n\n")
# Out:
# Number of documents per topic : [   67 43255  6997   281   119 18485  7806 14046 19228 13048 17166 22089
#    163 18598   134  2913   566   141  1136  6088   136    33 14011    34
#   2730  1183   314    85 50165  6782]
# ********************
# Most important clusters (by number of docs inside): [28  1 11  8 13  5 10  7 22  9  6  2 29 19 15 24 25 18 16 26  3 12 17 20
#  14  4 27  0 23 21]
# ********************
# Top words for index 28:
#
#
# ('khk', 40181)
# ('...', 10136)
# ('bir', 9185)
# ('adalet', 4845)
# ('hukuk', 4522)
# ('bu', 2922)
# ('kadar', 2152)
# ('hak', 2109)
# ('devam', 1932)
# ('khklilar', 1899)
# ('istiyoruz', 1818)
# ('degil', 1810)
# ('ulkenin', 1758)
# ('biz', 1744)
# ('olarak', 1697)
# ('insan', 1656)
# ('mucadele', 1625)
# ('olan', 1614)
# ('khklar', 1566)
# ('artik', 1540)
#
#
#
# Top words for index 1:
#
#
# ('bir', 18595)
# ('...', 13658)
# ("''", 4079)
# ('bu', 4004)
# ('``', 3887)
# ('var', 3392)
# ('degil', 3274)
# ('yok', 2878)
# ('kadar', 2827)
# ('ben', 2166)
# ('bile', 1613)
# ('iyi', 1597)
# ('boyle', 1568)
# ('olarak', 1564)
# ('olan', 1422)
# ('khk', 1371)
# ('insan', 1350)
# ("'", 1337)
# ('sadece', 1179)
# ('sonra', 1154)
#
#
#
# Top words for index 11:
#
#
# ('...', 10153)
# ('bir', 5028)
# ('``', 2292)
# ("''", 2175)
# ("'", 1792)
# ('gozaltina', 1340)
# ('yil', 1233)
# ('istanbul', 1215)
# ('kadin', 1215)
# ('tarafindan', 1206)
# ('gazeteci', 1204)
# ('ceza', 1087)
# ('karari', 1066)
# ('karar', 1010)
# ('baskani', 1009)
# ('olarak', 970)
# ('bu', 945)
# ('bugun', 941)
# ('sonra', 927)
# ('hakkinda', 926)
#
#
#
# Top words for index 8:
#
#
# ('...', 8047)
# ('bir', 3417)
# ('kadin', 3299)
# ('karsi', 2056)
# ('``', 1803)
# ("''", 1634)
# ('kadinlar', 1579)
# ('istanbul', 1257)
# ('haklari', 1092)
# ("'", 1078)
# ('gunu', 1022)
# ('devam', 989)
# ('bugun', 945)
# ('saat', 903)
# ('olarak', 890)
# ('birlikte', 819)
# ('mucadele', 812)
# ('insan', 766)
# ('kadinlarin', 765)
# ('adalet', 763)
#
#
#
# Top words for index 13:
#
#
# ('...', 8041)
# ('bir', 5259)
# ('``', 1663)
# ("''", 1542)
# ('olarak', 1240)
# ('kadin', 1151)
# ('bu', 1055)
# ("'", 974)
# ('var', 888)
# ('olan', 859)
# ('haklari', 840)
# ('1', 778)
# ('degil', 767)
# ('insan', 759)
# ('gore', 741)
# ('bin', 687)
# ('yok', 651)
# ('cocuk', 647)
# ('son', 645)
# ('yuzde', 644)
#
#
#
# Top words for index 5:
#
#
# ('khk', 6783)
# ('...', 6243)
# ('bir', 5555)
# ('suc', 2327)
# ('hukuk', 2023)
# ('ohal', 1975)
# ("''", 1524)
# ('``', 1417)
# ('olarak', 1315)
# ('ihrac', 1183)
# ('insan', 1074)
# ('yargi', 1004)
# ('gore', 991)
# ('olan', 958)
# ('yok', 935)
# ('bu', 913)
# ('ceza', 903)
# ('komisyonu', 902)
# ('olmayan', 890)
# ('karari', 881)
#
#
#
# Top words for index 10:
#
#
# ('khk', 6813)
# ('...', 5398)
# ('bir', 3869)
# ('insan', 1286)
# ('ihrac', 1153)
# ('bu', 1116)
# ('binlerce', 997)
# ('bin', 992)
# ('khkli', 797)
# ('!', 796)
# ('kisi', 763)
# ('olan', 763)
# ('6', 760)
# ('masum', 732)
# ('yildir', 684)
# ('askeri', 659)
# ('cocuklar', 647)
# ('cocuk', 619)
# ('fazla', 616)
# ('cezaevinde', 595)
#
#
#
# Top words for index 7:
#
#
# ('...', 6610)
# ('bir', 3810)
# ('cezaevinde', 2997)
# ('tutuklu', 1983)
# ('hasta', 1823)
# ('olan', 1691)
# ('hastasi', 1642)
# ('tahliye', 1584)
# ('kanser', 1339)
# ('bakanlik', 1262)
# ('yasindaki', 1103)
# ('var', 1015)
# ('yusuf', 1005)
# ('2', 946)
# ('6', 945)
# ('yildir', 934)
# ('ay', 889)
# ('engelli', 879)
# ('3', 830)
# ('bu', 806)
#
#
#
# Top words for index 22:
#
#
# ('the', 15402)
# ('of', 8604)
# ('to', 7349)
# ('in', 6779)
# ('...', 6488)
# ('and', 5323)
# ('a', 4775)
# ('is', 3734)
# ('for', 3606)
# ('on', 2818)
# ('that', 2003)
# ('are', 1868)
# ('with', 1811)
# ("'s", 1717)
# ('i', 1593)
# ('has', 1546)
# ('we', 1517)
# ('he', 1502)
# ('this', 1455)
# ('by', 1425)
#
#
#
# Top words for index 9:
#
#
# ('...', 4105)
# ('bir', 2918)
# ("'", 1159)
# ('dogu', 1034)
# ('uygur', 994)
# ('karsi', 822)
# ('``', 777)
# ('araciligiyla', 776)
# ("''", 771)
# ('turkiye', 704)
# ('cin', 689)
# ('turk', 675)
# ('kurt', 603)
# ('iran', 603)
# ('son', 533)
# ('tarafindan', 518)
# ('abd', 508)
# ('bu', 474)
# ('olarak', 455)
# ('kurdistan', 450)
#
#
#
# Top words for index 6:
#
#
# ('olsun', 2032)
# ('...', 1668)
# ('bir', 1173)
# ('gecmis', 678)
# ('cok', 673)
# ('rahmet', 528)
# ('khk', 525)
# ('diliyorum', 471)
# ('guzel', 452)
# ('allah', 386)
# ('iyi', 357)
# ('sevgili', 330)
# ('sabir', 318)
# ("'", 313)
# ('tesekkur', 308)
# ('ederim', 306)
# ('kutlu', 261)
# ('cennet', 259)
# ('hocam', 254)
# ('dilerim', 251)
#
#
#
# Top words for index 2:
#
#
# ('khk', 5900)
# ('...', 2454)
# ('tesekkur', 1026)
# ('olarak', 806)
# ('bir', 750)
# ('platformu', 726)
# ('ederiz', 596)
# ('sayin', 567)
# ('khkli', 515)
# ('il', 498)
# ('khklilar', 483)
# ('birlikte', 407)
# ('ziyaret', 400)
# ('platformlari', 388)
# ('bu', 381)
# ('tesekkurler', 380)
# ('aksam', 352)
# ('partisi', 334)
# ('khk54', 319)
# ('saglik', 313)
#
#
#
# Top words for index 29:
#
#
# ('...', 3253)
# ('genel', 1078)
# ('bir', 710)
# ('baskani', 550)
# ('baskanimiz', 540)
# ('hdp', 493)
# ('es', 448)
# ('il', 447)
# ("'", 426)
# ('chp', 383)
# ('anayasa', 333)
# ('``', 332)
# ('istanbul', 318)
# ("''", 288)
# ('secim', 286)
# ('milletvekili', 280)
# ('kemal', 275)
# ('baskan', 265)
# ('akp', 249)
# ('bu', 237)
#
#
#
# Top words for index 19:
#
#
# ('...', 1793)
# ('bir', 1672)
# ('khk', 642)
# ("''", 400)
# ('``', 354)
# ('ben', 342)
# ('sen', 317)
# ('guzel', 274)
# ('kadar', 251)
# ('yok', 249)
# ('var', 231)
# ('gun', 217)
# ('bu', 206)
# ('degil', 189)
# ('ey', 166)
# ('birliktebuyutelim', 163)
# ('iyi', 162)
# ('sana', 156)
# ('seni', 153)
# ('beni', 149)
#
#
#
# Top words for index 15:
#
#
# ('u', 1332)
# ('ji', 1144)
# ('bi', 890)
# ('li', 890)
# ('...', 840)
# ('e', 510)
# ('kurdi', 497)
# ('em', 482)
# ('me', 460)
# ('di', 424)
# ('ye', 394)
# ('bo', 393)
# ('xwe', 362)
# ('be', 319)
# ('ku', 287)
# ('zimane', 260)
# ('ez', 256)
# ('ser', 251)
# ('we', 249)
# ('kurd', 241)
#
#
#
# Top words for index 24:
#
#
# ('bir', 904)
# ('...', 884)
# ('bilge', 598)
# ('yusuf', 520)
# ('tunc', 464)
# ('diril', 434)
# ('gulistan', 434)
# ('gun', 385)
# ('doku', 362)
# ('kayip', 352)
# ('hurmuz', 349)
# ('gundur', 332)
# ('haber', 282)
# ('bal', 228)
# ('kacirilan', 217)
# ('mehmet', 215)
# ('sonra', 212)
# ('sorusturma', 207)
# ('khk', 199)
# ('etkin', 196)
#
#
#
# Top words for index 25:
#
#
# ('khk', 546)
# ('suc', 386)
# ('bir', 334)
# ('...', 325)
# ('zaman', 194)
# ('kanunun', 167)
# ('saymadigi', 162)
# ('ceza', 131)
# ('dolayi', 127)
# ('kimse', 120)
# ('fiilden', 106)
# ('bulunan', 105)
# ('yururlukte', 102)
# ('islendigi', 97)
# ('kimseye', 82)
# ('siddet', 82)
# ('hukuk', 77)
# ('38', 72)
# ('anayasa', 69)
# ('acikca', 69)
#
#
#
# Top words for index 18:
#
#
# ('...', 629)
# ('a', 584)
# ('la', 509)
# ('les', 270)
# ('le', 258)
# ('et', 248)
# ('des', 172)
# ('<', 168)
# ('selek', 164)
# ('pour', 149)
# ('du', 134)
# ('>', 130)
# ('adalet', 114)
# ('un', 108)
# ('une', 108)
# ('nuriyenin', 106)
# ('ozgurluk', 105)
# ('sahte', 104)
# ('delillerle', 104)
# ('tutsakliginin', 104)
#
#
#
# Top words for index 16:
#
#
# ('...', 334)
# ('der', 183)
# ('die', 165)
# ('in', 146)
# ('und', 128)
# ('hurmuz', 67)
# ('once', 66)
# ('geiin', 66)
# ('diril', 65)
# ('im', 64)
# ('fur', 64)
# ('khk', 62)
# ('ist', 59)
# ('den', 58)
# ('simuni', 55)
# ('das', 49)
# ('es', 47)
# ('von', 47)
# ('des', 47)
# ("diril'in", 45)
#
#
#
# Top words for index 26:
#
#
# ('i', 104)
# ('att', 101)
# ('...', 76)
# ('det', 66)
# ('och', 62)
# ('for', 57)
# ('ar', 56)
# ('om', 51)
# ('gundur', 49)
# ('som', 49)
# ('har', 48)
# ('khk', 45)
# ('av', 44)
# ('insan', 40)
# ('``', 37)
# ('inte', 37)
# ('pa', 37)
# ('turkiet', 36)
# ('med', 35)
# ('bir', 34)
#
#
#
# Top words for index 3:
#
#
# ('khk', 71)
# ('insan', 58)
# ('tv', 58)
# ('``', 53)
# ('...', 52)
# ('hayatini', 52)
# ('yasindaki', 51)
# ('cezaevinde', 51)
# ('nesrin', 51)
# ('ordu', 51)
# ('ilaclari', 51)
# ('verilmedigi', 51)
# ('gencosmanin', 51)
# ('kaybettigi', 50)
# ('biliyor', 50)
# ('adalet', 49)
# ('haklari', 49)
# ("turkiye'nin", 49)
# ('gundemi', 49)
# ('magduriyetler', 49)
#
#
#
# Top words for index 12:
#
#
# ('khk', 50)
# ('bir', 47)
# ('acil', 42)
# ('yardim', 42)
# ('...', 36)
# ('siddet', 33)
# ('hayatlari', 32)
# ('maruz', 31)
# ('yasal', 31)
# ('kriterlerden', 31)
# ('ev', 30)
# ('ici', 30)
# ('hatti', 30)
# ('emekleri', 30)
# ('tecrite', 30)
# ('gecede', 29)
# ('tum', 27)
# ('kalan', 26)
# ('aramaya', 25)
# ('firsat', 24)
#
#
#
# Top words for index 17:
#
#
# ('yaptigi', 59)
# ('cezaevinde', 57)
# ('gazeteci', 57)
# ('isini', 57)
# ('cdegildir', 54)
# ('gundur', 41)
# ('tutulan', 41)
# ('hapiste', 41)
# ('mesleki', 41)
# ('faaliyetleri', 41)
# ('sebebiyle', 41)
# ('ozgurluk', 38)
# ('gazetecilere', 38)
# ('urfent', 24)
# ('khk', 21)
# ('onundeki', 21)
# ('buyuk', 20)
# ('urfenticinozgurluk', 20)
# ('sussak', 20)
# ('guryilmaz', 18)
#
#
#
# Top words for index 20:
#
#
# ('khk', 64)
# ('bir', 38)
# ('maruz', 33)
# ('...', 26)
# ('edildiinsanlar', 26)
# ('hak', 21)
# ('hukuki', 19)
# ('ihrac', 16)
# ('mucadele', 15)
# ('islerinden', 15)
# ('khkli', 13)
# ('diyecek', 13)
# ('istiyor', 12)
# ('devam', 12)
# ('kadar', 12)
# ('edilmis', 12)
# ('is', 12)
# ('khklarla', 12)
# ('herhangi', 12)
# ('haklarini', 12)
#
#
#
# Top words for index 14:
#
#
# ('soru', 94)
# ('cevap', 94)
# ('ettigi', 48)
# ('tarihli', 48)
# ('onergelerime', 48)
# ('verilmedi', 47)
# ('vefat', 47)
# ('garibe', 47)
# ('gezer', 47)
# ('26102021', 47)
# ('0304202017012020', 47)
# ('gundur', 46)
# ('tarihinde', 46)
# ('verdigimiz', 46)
# ('sonraki', 46)
# ('onergeme', 46)
# ('09122021den', 46)
# ('22122021', 46)
# ('verilmedineredesiniz', 46)
# ('bir', 32)
#
#
#
# Top words for index 4:
#
#
# ('khk', 47)
# ('hak', 30)
# ('takipsizlik', 30)
# ('magdurlar', 30)
# ('ihlali', 30)
# ('beraat', 30)
# ('kararlarini', 30)
# ('lehine', 30)
# ('diken', 30)
# ('verdikleri', 30)
# ('savciliklarin', 30)
# ('durde', 29)
# ('mahkemeler', 28)
# ('khkzulmune', 28)
# ('bir', 24)
# ('...', 23)
# ('yok', 20)
# ('tanimama', 20)
# ('vskhk', 20)
# ('sayma', 18)
#
#
#
# Top words for index 27:
#
#
# ('bir', 31)
# ('vb', 27)
# ('parti', 26)
# ('grup', 26)
# ('kurum', 26)
# ('yapi', 26)
# ('orgut', 26)
# ('ideolojiyle', 26)
# ('siyasi', 25)
# ('dogrudan', 25)
# ('olusum', 25)
# ('khk', 24)
# ('platformlari', 20)
# ('...', 19)
# ('khkli', 19)
# ('by', 16)
# ('creative', 14)
# ('commons', 14)
# ('mesru', 13)
# ('kullanabilirsiniz', 13)
#
#
#
# Top words for index 0:
#
#
# ('--', 73)
# ('ulke', 16)
# ('haksiz', 16)
# ('hak', 16)
# ('yargilama', 16)
# ('ihsan', 16)
# ('insanimiz', 16)
# ('merhamet', 16)
# ('birilerinden', 16)
# ('ulufe', 16)
# ('hukukuadil', 16)
# ('hakkinihak', 16)
# ('gasplarinin', 16)
# ('onune', 15)
# ('khklilar', 15)
# ('gecilmesinikhklarin', 15)
# ('iptalini', 15)
# ('beklemiyoruz', 14)
# ('...', 13)
# ('yuzlerce', 13)
#
#
#
# Top words for index 23:
#
#
# ('cehenneme', 19)
# ('cani', 17)
# ('...', 12)
# ('rahat', 9)
# ('baskasinin', 9)
# ('khk', 8)
# ('yalniz', 8)
# ('ortenin', 8)
# ('perdesini', 8)
# ('kendiyle', 8)
# ('dolu', 7)
# ('basa', 6)
# ('isitip', 6)
# ('yemegini', 6)
# ('uyuyaninkapisini', 6)
# ('ancak', 5)
# ('cekeninyuregi', 5)
# ('duvarlari', 4)
# ('yanginiyla', 4)
# ('freisler', 4)
#
#
#
# Top words for index 21:
#
#
# ('khk', 19)
# ('edilen', 10)
# ('bakmayin', 10)
# ('istiyoruz', 10)
# ('iheryerde', 10)
# ('kurye', 10)
# ('haklarimizi', 10)
# ('taksici', 10)
# ('sebzeli', 10)
# ('boyaci', 10)
# ('olugunmuzagasp', 10)
# ('ahlak', 6)
# ('...', 5)
# ('haksizliga', 5)
# ('yanan', 5)
# ('den', 5)
# ('evlat', 5)
# ('yuregi', 5)
# ('hangi', 5)
# ('diyenler', 5)
